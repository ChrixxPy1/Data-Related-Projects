# %%
import pandas as pd
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt
df = pd.read_csv('C:\\Users\\Alozie Daberechi\\Downloads\\tmdb-movies.csv')
# %matplotlib inline
df.head(1)
# Out:
#        id    imdb_id  popularity     budget     revenue  original_title  \
# 0  135397  tt0369610   32.985763  150000000  1513528810  Jurassic World
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
#
#                         homepage         director            tagline  ...  \
# 0  http://www.jurassicworld.com/  Colin Trevorrow  The park is open.  ...
#
#                                             overview runtime  \
# 0  Twenty-two years after the events of Jurassic ...     124
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
#
#                                 production_companies release_date vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15       5562
#
#    vote_average  release_year    budget_adj   revenue_adj
# 0           6.5          2015  1.379999e+08  1.392446e+09
#
# [1 rows x 21 columns]

# %%
# !pip install -- seaborn

# %%
#Investigation Questions I answered with the TMDb Movie Dataset



#Which year has the highest release of movies?
#Which Movie Has The Highest Or Lowest Profit? Top 10 movies which earn highest profit?
#Movie with Highest And Lowest Budget?
#Which movie made the highest revenue and lowest as well?
#Movie with shorest and longest runtime?
#Which movie get the highest or lowest votes (Ratings).
#Which Year Has The Highest Profit Rate?
#Which length movies most liked by the audiences according to their popularity?
#Average Runtime Of Movies From Year To Year?
#How Does The Revenue And Popularity differs Budget And Runtime? And How Does Popularity Depends On Profit?

# %%
df.describe()
# Out:
#                   id    popularity        budget       revenue       runtime  \
# count   10866.000000  10866.000000  1.086600e+04  1.086600e+04  10866.000000
# mean    66064.177434      0.646441  1.462570e+07  3.982332e+07    102.070863
# std     92130.136561      1.000185  3.091321e+07  1.170035e+08     31.381405
# min         5.000000      0.000065  0.000000e+00  0.000000e+00      0.000000
# 25%     10596.250000      0.207583  0.000000e+00  0.000000e+00     90.000000
# 50%     20669.000000      0.383856  0.000000e+00  0.000000e+00     99.000000
# 75%     75610.000000      0.713817  1.500000e+07  2.400000e+07    111.000000
# max    417859.000000     32.985763  4.250000e+08  2.781506e+09    900.000000
#
#          vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  10866.000000  10866.000000  10866.000000  1.086600e+04  1.086600e+04
# mean     217.389748      5.974922   2001.322658  1.755104e+07  5.136436e+07
# ...

# %%
df.tail(4)
# Out:
#           id    imdb_id  popularity  budget  revenue  \
# 10862  20379  tt0060472    0.065543       0        0
# 10863  39768  tt0060161    0.065141       0        0
# 10864  21449  tt0061177    0.064317       0        0
# 10865  22293  tt0060666    0.035919   19000        0
#
#                  original_title  \
# 10862                Grand Prix
# 10863       Beregis Avtomobilya
# 10864    What's Up, Tiger Lily?
# 10865  Manos: The Hands of Fate
#
#                                                     cast homepage  \
# 10862  James Garner|Eva Marie Saint|Yves Montand|Tosh...      NaN
# 10863  Innokentiy Smoktunovskiy|Oleg Efremov|Georgi Z...      NaN
# 10864  Tatsuya Mihashi|Akiko Wakabayashi|Mie Hama|Joh...      NaN
# 10865  Harold P. Warren|Tom Neyman|John Reynolds|Dian...      NaN
#
#                  director                                            tagline  \
# 10862  John Frankenheimer  Cinerama sweeps YOU into a drama of speed and ...
# ...

# %%
df.isna().sum()
# Out:
# id                         0
# imdb_id                   10
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# homepage                7930
# director                  44
# tagline                 2824
# keywords                1493
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %%
df.fillna(0)
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10861      21  tt0060371    0.080598          0           0
# 10862   20379  tt0060472    0.065543          0           0
# 10863   39768  tt0060161    0.065141          0           0
# 10864   21449  tt0061177    0.064317          0           0
# 10865   22293  tt0060666    0.035919      19000           0
#
#                      original_title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# 3      Star Wars: The Force Awakens
# 4                         Furious 7
# ...

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates(inplace = True)
df.shape
# Out:
# (10865, 21)

# %%
df['release_date'] = pd.to_datetime(df['release_date'])
df.head(2)
# Out:
#        id    imdb_id  popularity     budget     revenue      original_title  \
# 0  135397  tt0369610   32.985763  150000000  1513528810      Jurassic World
# 1   76341  tt1392190   28.419936  150000000   378436354  Mad Max: Fury Road
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
#
#                         homepage         director             tagline  ...  \
# 0  http://www.jurassicworld.com/  Colin Trevorrow   The park is open.  ...
# 1    http://www.madmaxmovie.com/    George Miller  What a Lovely Day.  ...
#
#                                             overview runtime  \
# 0  Twenty-two years after the events of Jurassic ...     124
# 1  An apocalyptic story set in the furthest reach...     120
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
#
# ...

# %%
df.drop(['budget_adj','revenue_adj','overview','imdb_id','homepage','tagline'], axis = 1, inplace = True)
df.shape
# Out:
# (10865, 15)

# %%
print("These are the rows With Zero Values In The Budget Column:",df[(df['budget']==0)].shape[0])
print("These are the rows With Zero Values In The Revenue Column:",df[(df['revenue']==0)].shape[0])
# Out:
# These are the rows With Zero Values In The Budget Column: 5696
# These are the rows With Zero Values In The Revenue Column: 6016

# %%
#Which year has the highest release of movies?
data = df.groupby('release_year').count()['id']
#data
#make group of the data according to their release year and count the total number of movies in each year and pot.
data = df.groupby('release_year').count()['id'].plot(xticks = np.arange(1960,2016,5))

#set the figure size and labels
sns.set(rc={'figure.figsize':(10,5)})
plt.title("Year Vs Number Of Movies",fontsize = 14)
plt.xlabel('Release year',fontsize = 13)
plt.ylabel('Number Of Movies',fontsize = 13)
#set the style sheet
sns.set_style("whitegrid")

# %%
#Which Movie Has The Highest Or Lowest Profit? Top 10 movies which earn highest profit?
df['Movie_Profit'] = df['revenue'] - df['budget']
def find_minmax(x):
    #use the function 'idmin' to find the index of lowest profit movie.
    min_index = df[x].idxmin()
    
    #use the function 'idmax' to find the index of Highest profit movie.
    high_index = df[x].idxmax()
    
    high = pd.DataFrame(df.loc[high_index,:])
    low = pd.DataFrame(df.loc[min_index,:])
    
    #print the movie with high and low profit
    print("Movie Which Has Highest "+ x + " : ",df['original_title'][high_index])
    print("Movie Which Has Lowest "+ x + "  : ",df['original_title'][min_index])
    return pd.concat([high,low],axis = 1)

#call the find_minmax function.
find_minmax('Movie_Profit')
# Out:
# Movie Which Has Highest Movie_Profit :  Avatar
# Movie Which Has Lowest Movie_Profit  :  The Warrior's Way
#                                                                    1386  \
# id                                                                19995
# popularity                                                     9.432768
# budget                                                        237000000
# revenue                                                      2781505847
# original_title                                                   Avatar
# cast                  Sam Worthington|Zoe Saldana|Sigourney Weaver|S...
# director                                                  James Cameron
# keywords              culture clash|future|space war|space colony|so...
# runtime                                                             162
# genres                         Action|Adventure|Fantasy|Science Fiction
# production_companies  Ingenious Film Partners|Twentieth Century Fox ...
# ...

# %%
#make a plot which contain top 10 movies which earn highest profit.
#sort the 'Profit' column in decending order and store it in the new dataframe,
wer = pd.DataFrame(df['Movie_Profit'].sort_values(ascending = False))
wer['original_title'] = df['original_title']
data = list(map(str,(wer['original_title'])))
x = list(data[:10])
y = list(wer['Movie_Profit'][:10])

#make a plot usinf pointplot for top 10 profitable movies.
ax = sns.pointplot(x=y,y=x)

#setup the figure size
sns.set(rc={'figure.figsize':(10,5)})
#setup the title and labels of the plot.
ax.set_title("Top 10 Profitable Movies",fontsize = 15)
ax.set_xlabel("Profit",fontsize = 13)
sns.set_style("darkgrid")

# %%
#Above is a list of top 10 profitable movies

# %%
#find the movie with highest and lowest budget.
#use 'find_minmax' function which you made earlier.
#make sure that movie with budget zero didn't affect the result.
#so change the zero into NAN in budget column.
df['budget'] = df['budget'].replace(0,np.NAN)
find_minmax('budget')
# Out:
# Movie Which Has Highest budget :  The Warrior's Way
# Movie Which Has Lowest budget  :  Fear Clinic
#                                                                    2244  \
# id                                                                46528
# popularity                                                      0.25054
# budget                                                      425000000.0
# revenue                                                        11087569
# original_title                                        The Warrior's Way
# cast                  Kate Bosworth|Jang Dong-gun|Geoffrey Rush|Dann...
# director                                                     Sngmoo Lee
# keywords              assassin|small town|revenge|deception|super speed
# runtime                                                             100
# genres                        Adventure|Fantasy|Action|Western|Thriller
# production_companies                           Boram Entertainment Inc.
# ...

# %%
#make a plot which contain top 10 highest budget movies.
#sort the 'budget' column in decending order first, and store it in the new dataframe that you'll create.
new_sort = pd.DataFrame(df['budget'].sort_values(ascending = False))
new_sort['original_title'] = df['original_title']
data = list(map(str,(new_sort['original_title'])))

#extract the top 10 budget movies data from the list and dataframe.
x = list(data[:10])
y = list(new_sort['budget'][:10])

#plot the figure and setup the title and labels.
ax = sns.pointplot(x=y,y=x)
sns.set(rc={'figure.figsize':(10,5)})
ax.set_title("Top 10 High Budget Movies",fontsize = 15)
ax.set_xlabel("Budget",fontsize = 13)
sns.set_style("darkgrid")

# %%
# Movie with Largest And Lowest Earned Revenue?
find_minmax('revenue')
# Out:
# Movie Which Has Highest revenue :  Avatar
# Movie Which Has Lowest revenue  :  Wild Card
#                                                                    1386  \
# id                                                                19995
# popularity                                                     9.432768
# budget                                                      237000000.0
# revenue                                                      2781505847
# original_title                                                   Avatar
# cast                  Sam Worthington|Zoe Saldana|Sigourney Weaver|S...
# director                                                  James Cameron
# keywords              culture clash|future|space war|space colony|so...
# runtime                                                             162
# genres                         Action|Adventure|Fantasy|Science Fiction
# production_companies  Ingenious Film Partners|Twentieth Century Fox ...
# ...

# %%
#top 10 movies which made highest revenue.
#sort the 'revenue' column in decending order and store it in the new dataframe.
top_rev = pd.DataFrame(df['revenue'].sort_values(ascending = False))
top_rev['original_title'] = df['original_title']
dat = list(map(str,(top_rev["original_title"])))

#now extract the top 10 movies which madethe highst revenue
x = list(dat[:10])
y = list (top_rev['revenue'][:10])

#you can now plot the figure 
axs = sns.pointplot(x=y, y=x)
sns.set(rc = {'figure.figsize' : (12, 7)})
axs.set_title("Top 10 Movies With Highest Revenue")
axs.set_xlabel("Revenue", fontsize = 15)
sns.set_style("darkgrid")

# %%
#find the movie with longest and shortest runtime.

df['runtime'] = df['runtime'].replace(0,np.NaN)

find_minmax('runtime')
# Out:
# Movie Which Has Highest runtime :  The Story of Film: An Odyssey
# Movie Which Has Lowest runtime  :  Fresh Guacamole
#                                                                    3894  \
# id                                                               125336
# popularity                                                     0.006925
# budget                                                              NaN
# revenue                                                               0
# original_title                            The Story of Film: An Odyssey
# cast                  Mark Cousins|Jean-Michel Frodon|Cari Beauchamp...
# director                                                   Mark Cousins
# keywords              cinema|nouvelle vague|hindi cinema|cinema novo...
# runtime                                                           900.0
# genres                                                      Documentary
# ...

# %%
#movie with the longest and shortest runtime
info = pd.DataFrame(df['runtime'].sort_values(ascending = False))
info['original_title'] = df['original_title']
data = list(map(str,(info['original_title'])))

#extract the top 10 longest duraton movies data from the list and dataframe.
x = list(data[:10])
y = list(info['runtime'][:10])

#make the point plot and setup the title and labels.
ax = sns.pointplot(x=y,y=x)
sns.set(rc={'figure.figsize':(10,5)})
ax.set_title("Top 10 Longest Movies",fontsize = 15)
ax.set_xlabel("Runtime",fontsize = 13)
sns.set_style("darkgrid")

# %%
#From the graph, we can deduce that the movie :Generation Kill has the shortest runtime of >500 seconds
#While "The story of film: An Odyssey" has the longest runtime of 900 seconds

# %%
#find the movie with most and least votes.

find_minmax('vote_average')
# Out:
# Movie Which Has Highest vote_average :  The Story of Film: An Odyssey
# Movie Which Has Lowest vote_average  :  Transmorphers
#                                                                    3894  \
# id                                                               125336
# popularity                                                     0.006925
# budget                                                              NaN
# revenue                                                               0
# original_title                            The Story of Film: An Odyssey
# cast                  Mark Cousins|Jean-Michel Frodon|Cari Beauchamp...
# director                                                   Mark Cousins
# keywords              cinema|nouvelle vague|hindi cinema|cinema novo...
# runtime                                                           900.0
# genres                                                      Documentary
# ...

# %%
#top 10 highets rated movies.
#sort the 'vote_average' column in decending order and store it in the new dataframe.
hig =pd.DataFrame(df['vote_average'].sort_values(ascending = False))
hig ['original_title'] = df['original_title']

data = list(map(str, (hig['original_title'])))
#now extract the top 10 highest rated movies from the list and data frame
x = list(data[:10])
y = list(hig['vote_average'][:10])

#Plot this in a graph

qa = sns.pointplot(x=y, y=x)
sns.set(rc={"figure.figsize" : (10, 7)})
qa.set_title ("Top 10 Highest Rated Movies", fontsize = 20)
qa.set_xlabel('Vote Average', fontsize = 15)
sns.set_style('darkgrid')

# %%
#do year-wise analysis of profit earn by movies in each earn.
#take the average of profit made by movies in each year and plot.
#make the group of the data according to their release_year and find the mean profit and plot.

# %%
df.groupby('release_year')['Movie_Profit'].mean().plot(kind = 'line');
plt.title('Average vs Year');
plt.xlabel('Year');
plt.ylabel('Average');

# %%
#use groupby function and group the data according to their runtime.
#make a plot using their popularity and find which length movies are most popular.

#make the group of the data according to their runtime and find the mean popularity related to this and plot.

df.groupby('runtime')['popularity'].mean().plot(figsize = (13,5),xticks=np.arange(0,1000,100))

#setup the title of the figure
plt.title("Runtime Vs Popularity",fontsize = 14)

#setup the x-label and y-label of the plot.
plt.xlabel('Runtime',fontsize = 13)
plt.ylabel('Average Popularity',fontsize = 13)

#setup the figure size.
sns.set(rc={'figure.figsize':(10,5)})
sns.set_style("whitegrid")

# %%
#how the runtime of the movies differ year to year.

#make the group of the data according to their release_year and find the mean  related to this and plot

df.groupby('release_year').mean()['runtime'].plot(kind = 'line')

plt.title('Runtime vs Release Year')
plt.xlabel('Release Year')
plt.ylabel('Runtime')
sns.set_style('darkgrid')

# %%
#how does revenue change according to their budget.
#make a scatter plot using 'regplot' between ''revenue' and 'budget'.

ad = sns.regplot(x = df['revenue'], y = df['budget']);
ad.set_title('Revenue vs Budget', fontsize = 15)
ad.set_xlabel('Revenue', fontsize = 15)
ad.set_ylabel('Budget', fontsize = 15)

sns.set_style('darkgrid')



#find the correlation between them
#convert zero into NAN in budget and revenue column for the exact calculation.


df['revenue'] = df['revenue'].replace(0, np.NAN)
df['Movie_Profit'] = df['Movie_Profit'].replace(0, np.NAN)
df['budget'] = df['budget'].replace(0, np.NAN)
daa_corr = df.corr()
print('The correlation between Revenue and Budget is : ', daa_corr.loc['revenue', 'budget'])
# Out:
# The correlation between Revenue and Budget is :  0.6885561524636727

# %%
#how does vote average(ratings) change according to the release year.
#make a scatter plot using 'regplot' between 'year' and 'vote average'.

af = sns.regplot(x = df['release_year'], y = df['vote_average']);
af.set_title('Release Year vs Vote Average', fontsize= 15)
af.set_xlabel('Vote Average', fontsize = 15)
af.set_ylabel('Release Year', fontsize = 15)
# Out:
# Text(0, 0.5, 'Release Year')

# %%
#how does vote average(ratings) change according to the release year.

af = sns.regplot(x=df['popularity'],y=df['Movie_Profit'],color='c')

#setup the title and the labels of the scatter plot.
af.set_title("Popularity Vs Profit",fontsize=13)
af.set_xlabel("Popularity",fontsize=12)
af.set_ylabel("Profit",fontsize=12)

#setup the figure size.
sns.set(rc={'figure.figsize':(6,4)})
sns.set_style("whitegrid")

#find the correlation between them.
print("Correlation Between Popularity And Profit : ",daa_corr.loc['popularity','Movie_Profit'])
# Out:
# Correlation Between Popularity And Profit :  0.6159162443059019
